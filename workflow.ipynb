# %%
import geopandas as gpd
import gpxpy
import gpxpy.gpx
import pandas as pd
from shapely.geometry import LineString
from pykml.factory import KML_ElementMaker as KML
import glob
import os
import subprocess

# %%
## Si estas en el sistema operativo Linux
subprocess.run(["bash", "code/download_gpx.sh"])
# Out:
# --2024-10-13 14:46:18--  https://www.dropbox.com/scl/fo/8z94chsvow2jdsiqp671y/AE_En7cxUwPiObSOGeiH8vk?rlkey=lti74t6t38wog9h9uo3v2wzqk&st=n17xps6h&dl=0
# Resolviendo www.dropbox.com (www.dropbox.com)... 162.125.68.18, 2620:100:6024:18::a27d:4412
# Conectando con www.dropbox.com (www.dropbox.com)[162.125.68.18]:443... conectado.
# Petición HTTP enviada, esperando respuesta...
# 302 Found
# Ubicación: https://ucbf870f77f80d0efc0c94e00d9a.dl.dropboxusercontent.com/zip_download_get/B_xdh3hALoAHVLqtnvHmRVwXgtbydvgrkSYh5pyyP2CgUF1PxbmAKynwrhL0Q4fUuqbzZcNkYXu8OfmrcPELiumZuX6UknPUzbPguMHRmlwuiQ# [siguiente]
# --2024-10-13 14:46:19--  https://ucbf870f77f80d0efc0c94e00d9a.dl.dropboxusercontent.com/zip_download_get/B_xdh3hALoAHVLqtnvHmRVwXgtbydvgrkSYh5pyyP2CgUF1PxbmAKynwrhL0Q4fUuqbzZcNkYXu8OfmrcPELiumZuX6UknPUzbPguMHRmlwuiQ
# Resolviendo ucbf870f77f80d0efc0c94e00d9a.dl.dropboxusercontent.com (ucbf870f77f80d0efc0c94e00d9a.dl.dropboxusercontent.com)... 162.125.68.15, 2620:100:6024:15::a27d:440f
# Conectando con ucbf870f77f80d0efc0c94e00d9a.dl.dropboxusercontent.com (ucbf870f77f80d0efc0c94e00d9a.dl.dropboxusercontent.com)[162.125.68.15]:443... conectado.
# Petición HTTP enviada, esperando respuesta...
# 200 OK
# Longitud: 117781 (115K) [application/zip]
# Guardando como: ‘track_data/salidas_campo_gpx.zip’
#      0K .......... .......... .......... .......... .......... 43%  122K 1s
#     50K ..
# ........ .......... .......... .......... .......... 86%  353K 0s
#    100K .......... .....                                      100% 11,0M=0,6s
#
# 2024-10-13 14:46:19 (208 KB/s) - ‘track_data/salidas_campo_gpx.zip’ guardado [117781/117781]
#
# --2024-10-13 14:46:19--  https://www.dropbox.com/scl/fo/8z94chsvow2jdsiqp671y/AE_En7cxUwPiObSOGeiH8vk?rlkey=lti74t6t38wog9h9uo3v2wzqk&st=n17xps6h&dl=0
# Resolviendo www.dropbox.com (www.dropbox.com)... 162.125.68.18, 2620:100:6024:18::a27d:4412
# Conectando con www.dropbox.com (www.dropbox.com)[162.125.68.18]:443... conectado.
# Petición HTTP enviada, esperando respuesta...
# 302 Found
# Ubicación: https://uc732e4b5d94d8ef934c1b7d9471.dl.dropboxusercontent.com/zip_download_get/B_y1c1jz7sB8FWBq2MaJo32AWPmPNW4gmcz6hGJWpl4xitjwFwxEvRc_cCNA7VLiajQdVEvJxA50ye_-k0nMt6jItqeOzW6cnRVjYN2VDJFgdw# [siguiente]
# --2024-10-13 14:46:20--  https://uc732e4b5d94d8ef934c1b7d9471.dl.dropboxusercontent.com/zip_download_get/B_y1c1jz7sB8FWBq2MaJo32AWPmPNW4gmcz6hGJWpl4xitjwFwxEvRc_cCNA7VLiajQdVEvJxA50ye_-k0nMt6jItqeOzW6cnRVjYN2VDJFgdw
# Resolviendo uc732e4b5d94d8ef934c1b7d9471.dl.dropboxusercontent.com (uc732e4b5d94d8ef934c1b7d9471.dl.dropboxusercontent.com)... 162.125.68.15, 2620:100:6024:15::a27d:440f
# Conectando con uc732e4b5d94d8ef934c1b7d9471.dl.dropboxusercontent.com (uc732e4b5d94d8ef934c1b7d9471.dl.dropboxusercontent.com)[162.125.68.15]:443... conectado.
# Petición HTTP enviada, esperando respuesta...
# 200 OK
# Longitud: 117781 (115K) [application/zip]
# Guardando como: ‘track_data/salidas_campo_gpx.zip’
#
#      0K .......... .......... .
# Archive:  track_data/salidas_campo_gpx.zip
# ......... .......... .......... 43%  120K 1s
#     50K .......... .......... .......... .......... .......... 86%  373K 0s
#    100K .......... .....                                      100% 13,8M=0,6s
#
# 2024-10-13 14:46:21 (209 KB/s) - ‘track_data/salidas_campo_gpx.zip’ guardado [117781/117781]
#
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
# replace track_data/2024-07-26 085002__20240726_0850.gpx? [y]es, [n]o, [A]ll, [N]one, [r]ename:  NULL
# (EOF or read error, treating as "[N]one" ...)
# CompletedProcess(args=['bash', 'code/download_gpx.sh'], returncode=0)

# %%
tracks = glob.glob(r"track_data/*.gpx")

# %%
def mi_ign_track(gpx_file):
    # Read your GPX file
    with open(gpx_file, 'r') as gpx_file:
        gpx = gpxpy.parse(gpx_file)

    # Initialize list to store LineString objects
    lines = []

    # Extract data from GPX
    for track in gpx.tracks:
        for segment in track.segments:
            points = [(point.longitude, point.latitude) for point in segment.points]
            line = LineString(points)
            lines.append(line)

    # Create a GeoDataFrame with the LineString objects
    gdf = gpd.GeoDataFrame(geometry=lines)

    # Set the coordinate reference system (CRS) to WGS84
    gdf.set_crs(epsg=4326, inplace=True)

    return gdf

# %%
all_tracks = []

for track in range(len(tracks)):
  temp_track = mi_ign_track(tracks[track])
  temp_track["name"] = tracks[track].replace(".gpx", "")
  temp_track[['date', 'ID']] = temp_track['name'].str.split(' ', expand=True)
  all_tracks.append(temp_track)

# %%
gdftracks = gpd.GeoDataFrame(pd.concat(all_tracks, ignore_index=True))

# %%
if not os.path.isdir("track_results/"):
  os.makedirs("track_results/")

# %%
gdftracks.to_file("track_results/senderos_salidas_campo.shp")

# %%
## De nuevo si estas en un sistema operativo Linux
subprocess.run(["Rscript", "code/leaflet_script.R"])
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Linking to GEOS 3.12.2, GDAL 3.9.2, PROJ 9.5.0; sf_use_s2() is TRUE
# CompletedProcess(args=['Rscript', 'code/leaflet_script.R'], returncode=0)
